# %%
import pandas as pd
import numpy as np
import datetime
import math

# %% [markdown]
# # Reading data

# %%
df_l = pd.read_csv('laliga-match-scores.csv', parse_dates = ['date'])
df_l.head()
# Out:
#    Unnamed: 0  day       date   time      home  xg_home score  xg_away  \
# 0           0  Fri 2021-08-13  21:00  Valencia      1.3   1–0      1.2
# 1           1  Sat 2021-08-14  19:30     Cádiz      0.4   1–1      1.0
# 2           2  Sat 2021-08-14  19:30  Mallorca      0.4   1–1      0.9
# 3           3  Sat 2021-08-14  22:00   Osasuna      0.8   0–0      0.7
# 4           4  Sat 2021-08-14  22:00    Alavés      1.7   1–4      1.8
#
#           away  attendance                     venue                   referee
# 0       Getafe      9868.0       Estadio de Mestalla                 Jesús Gil
# 1      Levante      6941.0  Estadio Nuevo Mirandilla            Santiago Jaime
# 2        Betis      6279.0          Iberostar Estadi       Antonio Matéu Lahoz
# 3     Espanyol      6715.0          Estadio El Sadar  Miguel Ángel Ortiz Arias
# 4  Real Madrid      3968.0   Estadio de Mendizorroza                César Soto

# %%
df_p = pd.read_csv('premierleague-match-scores.csv', parse_dates = ['date'])
df_p.head()
# Out:
#    Unnamed: 0  day       date   time            home  xg_home score  xg_away  \
# 0           0  Fri 2021-08-13  20:00       Brentford      1.3   2–0      1.4
# 1           1  Sat 2021-08-14  12:30  Manchester Utd      1.5   5–1      0.6
# 2           2  Sat 2021-08-14  15:00         Watford      1.2   3–2      1.1
# 3           3  Sat 2021-08-14  15:00         Chelsea      0.9   3–0      0.3
# 4           4  Sat 2021-08-14  15:00         Everton      2.4   3–1      0.7
#
#              away  attendance                        venue         referee
# 0         Arsenal     16479.0  Brentford Community Stadium  Michael Oliver
# 1    Leeds United     72732.0                 Old Trafford    Paul Tierney
# 2     Aston Villa     20051.0        Vicarage Road Stadium       Mike Dean
# 3  Crystal Palace     38965.0              Stamford Bridge   Jonathan Moss
# 4     Southampton     38487.0                Goodison Park     Andy Madley

# %%
df_s = pd.read_csv('seriea-match-scores.csv', parse_dates = ['date'])
df_s.head()
# Out:
#    Unnamed: 0  day       date   time           home  xg_home score  xg_away  \
# 0           0  Sat 2021-08-21  18:30  Hellas Verona      2.1   2–3      1.4
# 1           1  Sat 2021-08-21  18:30          Inter      1.5   4–0      1.0
# 2           2  Sat 2021-08-21  20:45         Empoli      1.3   1–3      1.3
# 3           3  Sat 2021-08-21  20:45         Torino      1.3   1–2      1.0
# 4           4  Sun 2021-08-22  18:30        Bologna      1.5   3–2      1.6
#
#           away  attendance                          venue          referee
# 0     Sassuolo      5448.0  Stadio Marc'Antonio Bentegodi     Manuel Volpi
# 1        Genoa     27402.0         Stadio Giuseppe Meazza   Valerio Marini
# 2        Lazio      3655.0        Stadio Carlo Castellani     Simone Sozza
# 3     Atalanta      3475.0      Stadio Olimpico di Torino   Daniele Chiffi
# 4  Salernitana      8375.0         Stadio Renato Dall'Ara  Antonio Rapuano

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Removing Unnamed column.

# %%
df_l.drop(['Unnamed: 0', 'day', 'time'], axis = 1, inplace = True)
df_l.head()
# Out:
#         date      home  xg_home score  xg_away         away  attendance  \
# 0 2021-08-13  Valencia      1.3   1–0      1.2       Getafe      9868.0
# 1 2021-08-14     Cádiz      0.4   1–1      1.0      Levante      6941.0
# 2 2021-08-14  Mallorca      0.4   1–1      0.9        Betis      6279.0
# 3 2021-08-14   Osasuna      0.8   0–0      0.7     Espanyol      6715.0
# 4 2021-08-14    Alavés      1.7   1–4      1.8  Real Madrid      3968.0
#
#                       venue                   referee
# 0       Estadio de Mestalla                 Jesús Gil
# 1  Estadio Nuevo Mirandilla            Santiago Jaime
# 2          Iberostar Estadi       Antonio Matéu Lahoz
# 3          Estadio El Sadar  Miguel Ángel Ortiz Arias
# 4   Estadio de Mendizorroza                César Soto

# %%
df_p.drop(['Unnamed: 0', 'day', 'time'] , axis = 1, inplace = True)
df_p.head()
# Out:
#         date            home  xg_home score  xg_away            away  \
# 0 2021-08-13       Brentford      1.3   2–0      1.4         Arsenal
# 1 2021-08-14  Manchester Utd      1.5   5–1      0.6    Leeds United
# 2 2021-08-14         Watford      1.2   3–2      1.1     Aston Villa
# 3 2021-08-14         Chelsea      0.9   3–0      0.3  Crystal Palace
# 4 2021-08-14         Everton      2.4   3–1      0.7     Southampton
#
#    attendance                        venue         referee
# 0     16479.0  Brentford Community Stadium  Michael Oliver
# 1     72732.0                 Old Trafford    Paul Tierney
# 2     20051.0        Vicarage Road Stadium       Mike Dean
# 3     38965.0              Stamford Bridge   Jonathan Moss
# 4     38487.0                Goodison Park     Andy Madley

# %%
df_s.drop(['Unnamed: 0', 'day', 'time'], axis = 1, inplace = True)
df_s.head()
# Out:
#         date           home  xg_home score  xg_away         away  attendance  \
# 0 2021-08-21  Hellas Verona      2.1   2–3      1.4     Sassuolo      5448.0
# 1 2021-08-21          Inter      1.5   4–0      1.0        Genoa     27402.0
# 2 2021-08-21         Empoli      1.3   1–3      1.3        Lazio      3655.0
# 3 2021-08-21         Torino      1.3   1–2      1.0     Atalanta      3475.0
# 4 2021-08-22        Bologna      1.5   3–2      1.6  Salernitana      8375.0
#
#                            venue          referee
# 0  Stadio Marc'Antonio Bentegodi     Manuel Volpi
# 1         Stadio Giuseppe Meazza   Valerio Marini
# 2        Stadio Carlo Castellani     Simone Sozza
# 3      Stadio Olimpico di Torino   Daniele Chiffi
# 4         Stadio Renato Dall'Ara  Antonio Rapuano

# %% [markdown]
# Check for NaN.

# %% [markdown]
# This function fills the attendance of a stadium with the average attendance only when the value is NaN for matches outside the Covid period.

# %%
def att_clean(s, att_map):
    for index, value in s.attendance.iteritems():
        if np.isnan(value) and not (datetime.datetime(2020, 4, 1) < s.date[index] < datetime.datetime(2021, 8, 1)):
            s.at[index, 'attendance'] = att_map.get(s.at[index, 'venue'])

# %%
l_att_map = df_l.groupby('venue').mean()['attendance'].apply(lambda x: x if np.isnan(x) else int(math.floor(x)) ).to_dict()

#that season rm had 0 attendance 
l_att_map['Estadio Alfredo Di Stéfano'] = 0
l_att_map
# Out:
# {'Camp Nou': 68250.0,
#  'Coliseum Alfonso Pérez': 10203.0,
#  'Estadi Municipal de Montilivi': 10686.0,
#  'Estadio Alfredo Di Stéfano': 0,
#  'Estadio Benito Villamarín': 45231.0,
#  'Estadio Ciudad de Valencia': 18160.0,
#  'Estadio El Alcoraz': 6604.0,
#  'Estadio El Sadar': 16443.0,
#  'Estadio La Rosaleda': 20333.0,
#  'Estadio Manuel Martínez Valero': 15033.0,
#  'Estadio Municipal José Zorrilla': 19339.0,
#  'Estadio Municipal de Anoeta': 24460.0,
#  'Estadio Municipal de Butarque': 10202.0,
#  'Estadio Municipal de Ipurúa': 5359.0,
#  'Estadio Municipal de Riazor': 20542.0,
#  'Estadio Nuevo Los Cármenes': 14774.0,
#  'Estadio Nuevo Mirandilla': 14055.0,
#  'Estadio Ramón Sánchez Pizjuán': 33594.0,
#  'Estadio San Mamés': 41470.0,
#  'Estadio Santiago Bernabéu': 58349.0,
#  'Estadio Wanda Metropolitano': 53306.0,
#  'Estadio de Balaídos': 14958.0,
#  'Estadio de Gran Canaria': 16183.0,
#  'Estadio de Mendizorroza': 15860.0,
#  'Estadio de Mestalla': 35693.0,
#  'Estadio de la Cerámica': 15890.0,
#  'Estadio del Rayo Vallecano': 9897.0,
#  'Iberostar Estadi': 13581.0,
#  'RCDE Stadium': 19241.0,
#  'San Mamés': 37532.0}

# %%
att_clean(df_l, l_att_map)
df_l.isna().sum()
# Out:
# date            0
# home            0
# xg_home         0
# score           0
# xg_away         0
# away            0
# attendance    486
# venue           0
# referee         0
# dtype: int64

# %% [markdown]
# Cleaning attendance for the Premier League.

# %%
p_att_map = df_p.groupby('venue').mean()['attendance'].apply(lambda x: x if np.isnan(x) else int(math.floor(x)) ).to_dict()
p_att_map
# Out:
# {'Anfield': 50543,
#  'Bet365 Stadium': 29279,
#  'Bramall Lane': 29251,
#  'Brentford Community Stadium': 16917,
#  'Cardiff City Stadium': 31407,
#  'Carrow Road': 26916,
#  'Craven Cottage': 22240,
#  'Elland Road': 34892,
#  'Emirates Stadium': 58311,
#  'Etihad Stadium': 53076,
#  'Goodison Park': 37870,
#  'King Power Stadium': 31664,
#  'Liberty Stadium': 20622,
#  'London Stadium': 56837,
#  'Molineux Stadium': 30564,
#  'Old Trafford': 73024,
#  'Selhurst Park': 24478,
#  "St. James' Park": 50317,
#  "St. Mary's Stadium": 29532,
#  'Stamford Bridge': 38696,
#  'The American Express Community Stadium': 29849,
#  'The Hawthorns': 23562,
#  "The John Smith's Stadium": 23621,
#  'Tottenham Hotspur Stadium': 55281,
#  'Turf Moor': 19956,
#  'Vicarage Road Stadium': 20395,
#  'Villa Park': 40712,
#  'Vitality Stadium': 10565,
#  'Wembley Stadium': 61169}

# %% [markdown]
# Cleaning attendance for the Serie A.

# %%
s_att_map = df_s.groupby('venue').mean()['attendance'].apply(lambda x: x if np.isnan(x) else int(math.floor(x)) ).to_dict()
s_att_map
# Out:
# {'Allianz Stadium': 33329,
#  'Dacia Arena': 16550,
#  'Sardegna Arena': 12886,
#  'Stadio Alberto Picco': 6708,
#  'Stadio Arechi': 15073,
#  'Stadio Artemio Franchi': 26644,
#  "Stadio Atleti Azzurri d'Italia": 15918,
#  'Stadio Benito Stirpe': 13358,
#  'Stadio Carlo Castellani': 7988,
#  'Stadio Ciro Vigorito': 10672,
#  'Stadio Città del Tricolore': 10443,
#  'Stadio Comunale Luigi Ferraris': 17736,
#  'Stadio Comunale Via Del Mare': 23295,
#  'Stadio Dino Manuzzi': 1000,
#  'Stadio Ennio Tardini': 14724,
#  'Stadio Ezio Scida': 10298,
#  'Stadio Giuseppe Meazza': 51374,
#  "Stadio Marc'Antonio Bentegodi": 14087,
#  'Stadio Mario Rigamonti': 14688,
#  'Stadio Olimpico': 33961,
#  'Stadio Olimpico di Torino': 16855,
#  'Stadio Paolo Mazza': 13319,
#  'Stadio Pierluigi Penzo': 6647,
#  "Stadio Renato Dall'Ara": 19483,
#  'Stadio San Paolo': 32057,
#  "Stadio Sant'Elia": 14650}

# %%
att_clean(df_s, s_att_map)
df_s.isna().sum()
# Out:
# date            0
# home            0
# xg_home         0
# score           0
# xg_away         0
# away            0
# attendance    460
# venue           0
# referee         0
# dtype: int64

# %% [markdown]
# Adding a goals column.

# %%
g_home = []
g_away = []

# %%
def score(s):
    g_home.append(int(s[0]))
    g_away.append(int(s[2]))
    return s
def score_clean(df):
    df.score.apply(score)

# %%
score_clean(df_l)
df_l['g_home'] = g_home
df_l['g_away'] = g_away
df_l.head()
# Out:
#         date      home  xg_home score  xg_away         away  attendance  \
# 0 2021-08-13  Valencia      1.3   1–0      1.2       Getafe      9868.0
# 1 2021-08-14     Cádiz      0.4   1–1      1.0      Levante      6941.0
# 2 2021-08-14  Mallorca      0.4   1–1      0.9        Betis      6279.0
# 3 2021-08-14   Osasuna      0.8   0–0      0.7     Espanyol      6715.0
# 4 2021-08-14    Alavés      1.7   1–4      1.8  Real Madrid      3968.0
#
#                       venue                   referee  g_home  g_away
# 0       Estadio de Mestalla                 Jesús Gil       1       0
# 1  Estadio Nuevo Mirandilla            Santiago Jaime       1       1
# 2          Iberostar Estadi       Antonio Matéu Lahoz       1       1
# 3          Estadio El Sadar  Miguel Ángel Ortiz Arias       0       0
# 4   Estadio de Mendizorroza                César Soto       1       4

# %%
score_clean(df_p)
df_p['g_home'] = g_home
df_p['g_away'] = g_away
df_p.head()
# Out:
#         date            home  xg_home score  xg_away            away  \
# 0 2021-08-13       Brentford      1.3   2–0      1.4         Arsenal
# 1 2021-08-14  Manchester Utd      1.5   5–1      0.6    Leeds United
# 2 2021-08-14         Watford      1.2   3–2      1.1     Aston Villa
# 3 2021-08-14         Chelsea      0.9   3–0      0.3  Crystal Palace
# 4 2021-08-14         Everton      2.4   3–1      0.7     Southampton
#
#    attendance                        venue         referee  g_home  g_away
# 0     16479.0  Brentford Community Stadium  Michael Oliver       2       0
# 1     72732.0                 Old Trafford    Paul Tierney       5       1
# 2     20051.0        Vicarage Road Stadium       Mike Dean       3       2
# 3     38965.0              Stamford Bridge   Jonathan Moss       3       0
# 4     38487.0                Goodison Park     Andy Madley       3       1

# %%
score_clean(df_s)
df_s['g_home'] = g_home
df_s['g_away'] = g_away
df_s.head()
# Out:
#         date           home  xg_home score  xg_away         away  attendance  \
# 0 2021-08-21  Hellas Verona      2.1   2–3      1.4     Sassuolo      5448.0
# 1 2021-08-21          Inter      1.5   4–0      1.0        Genoa     27402.0
# 2 2021-08-21         Empoli      1.3   1–3      1.3        Lazio      3655.0
# 3 2021-08-21         Torino      1.3   1–2      1.0     Atalanta      3475.0
# 4 2021-08-22        Bologna      1.5   3–2      1.6  Salernitana      8375.0
#
#                            venue          referee  g_home  g_away
# 0  Stadio Marc'Antonio Bentegodi     Manuel Volpi       2       3
# 1         Stadio Giuseppe Meazza   Valerio Marini       4       0
# 2        Stadio Carlo Castellani     Simone Sozza       1       3
# 3      Stadio Olimpico di Torino   Daniele Chiffi       1       2
# 4         Stadio Renato Dall'Ara  Antonio Rapuano       3       2

# %% [markdown]
# Adding a results column.

# %%
def result(df):
    result = []
    for index in range(len(df)):
        if df['g_home'][index] > df['g_away'][index]:
            result.append(df['home'][index])
        elif df['g_home'][index] < df['g_away'][index]:
            result.append(df['away'][index])
        else:
            result.append('Draw')
    return result

# %%
df_l['result'] = result(df_l)
df_l.head()
# Out:
#         date      home  xg_home score  xg_away         away  attendance  \
# 0 2021-08-13  Valencia      1.3   1–0      1.2       Getafe      9868.0
# 1 2021-08-14     Cádiz      0.4   1–1      1.0      Levante      6941.0
# 2 2021-08-14  Mallorca      0.4   1–1      0.9        Betis      6279.0
# 3 2021-08-14   Osasuna      0.8   0–0      0.7     Espanyol      6715.0
# 4 2021-08-14    Alavés      1.7   1–4      1.8  Real Madrid      3968.0
#
#                       venue                   referee  g_home  g_away  \
# 0       Estadio de Mestalla                 Jesús Gil       1       0
# 1  Estadio Nuevo Mirandilla            Santiago Jaime       1       1
# 2          Iberostar Estadi       Antonio Matéu Lahoz       1       1
# 3          Estadio El Sadar  Miguel Ángel Ortiz Arias       0       0
# 4   Estadio de Mendizorroza                César Soto       1       4
#
#         result
# 0     Valencia
# 1         Draw
# 2         Draw
# 3         Draw
# 4  Real Madrid

# %%
df_p['result'] = result(df_p)
df_p.head()
# Out:
#         date            home  xg_home score  xg_away            away  \
# 0 2021-08-13       Brentford      1.3   2–0      1.4         Arsenal
# 1 2021-08-14  Manchester Utd      1.5   5–1      0.6    Leeds United
# 2 2021-08-14         Watford      1.2   3–2      1.1     Aston Villa
# 3 2021-08-14         Chelsea      0.9   3–0      0.3  Crystal Palace
# 4 2021-08-14         Everton      2.4   3–1      0.7     Southampton
#
#    attendance                        venue         referee  g_home  g_away  \
# 0     16479.0  Brentford Community Stadium  Michael Oliver       2       0
# 1     72732.0                 Old Trafford    Paul Tierney       5       1
# 2     20051.0        Vicarage Road Stadium       Mike Dean       3       2
# 3     38965.0              Stamford Bridge   Jonathan Moss       3       0
# 4     38487.0                Goodison Park     Andy Madley       3       1
#
#            result
# 0       Brentford
# 1  Manchester Utd
# 2         Watford
# 3         Chelsea
# 4         Everton

# %%
df_s['result'] = result(df_s)
df_s.head()
# Out:
#         date           home  xg_home score  xg_away         away  attendance  \
# 0 2021-08-21  Hellas Verona      2.1   2–3      1.4     Sassuolo      5448.0
# 1 2021-08-21          Inter      1.5   4–0      1.0        Genoa     27402.0
# 2 2021-08-21         Empoli      1.3   1–3      1.3        Lazio      3655.0
# 3 2021-08-21         Torino      1.3   1–2      1.0     Atalanta      3475.0
# 4 2021-08-22        Bologna      1.5   3–2      1.6  Salernitana      8375.0
#
#                            venue          referee  g_home  g_away    result
# 0  Stadio Marc'Antonio Bentegodi     Manuel Volpi       2       3  Sassuolo
# 1         Stadio Giuseppe Meazza   Valerio Marini       4       0     Inter
# 2        Stadio Carlo Castellani     Simone Sozza       1       3     Lazio
# 3      Stadio Olimpico di Torino   Daniele Chiffi       1       2  Atalanta
# 4         Stadio Renato Dall'Ara  Antonio Rapuano       3       2   Bologna

# %% [markdown]
# # Win Stats

# %%
df_l.result.value_counts()
# Out:
# Draw               521
# Barcelona          124
# Real Madrid        120
# Atlético Madrid    110
# Sevilla             95
# Betis               78
# Real Sociedad       77
# Villarreal          77
# Valencia            72
# Getafe              61
# Athletic Club       61
# Celta Vigo          56
# Alavés              55
# Levante             53
# Eibar               42
# Espanyol            41
# Granada             37
# Osasuna             36
# Leganés             31
# Valladolid          24
# Girona              23
# Elche               19
# Cádiz               19
# Mallorca            19
# Rayo Vallecano      19
# Huesca              14
# La Coruña            6
# Las Palmas           5
# Málaga               5
# Name: result, dtype: int64

# %%
df_p.result.value_counts()
# Out:
# Draw               433
# Manchester City    146
# Liverpool          131
# Chelsea            102
# Tottenham          102
# Manchester Utd      99
# Arsenal             94
# Leicester City      79
# West Ham            70
# Everton             69
# Newcastle Utd       60
# Crystal Palace      59
# Wolves              58
# Burnley             57
# Southampton         52
# Brighton            48
# Watford             39
# Aston Villa         38
# Bournemouth         33
# Leeds United        27
# Sheffield Utd       21
# Brentford           13
# Fulham              12
# Huddersfield        12
# West Brom           11
# Norwich City        10
# Cardiff City        10
# Swansea City         8
# Stoke City           7
# Name: result, dtype: int64

# %%
df_s.result.value_counts()
# Out:
# Draw             470
# Juventus         127
# Napoli           118
# Inter            117
# Milan            106
# Lazio            101
# Atalanta          98
# Roma              98
# Sampdoria         68
# Sassuolo          64
# Fiorentina        64
# Torino            60
# Bologna           56
# Udinese           56
# Cagliari          47
# Hellas Verona     44
# Genoa             43
# Parma             27
# SPAL              24
# Empoli            20
# Spezia            19
# Crotone           15
# Benevento         13
# Chievo            12
# Lecce              9
# Salernitana        7
# Venezia            6
# Brescia            6
# Frosinone          5
# Name: result, dtype: int64
